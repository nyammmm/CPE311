# %% [markdown]
# <a href="https://colab.research.google.com/github/nyammmm/CPE311/blob/main/Seatwork%206.1/Seatwork6.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
filepath = '/content/teams.csv'

# %%
df = pd.read_csv(filepath)
df
# Out:
#         id  year                     name                          park  wins  \
# 0        1  1871     Boston Red Stockings           South End Grounds I    20
# 1        2  1871  Chicago White Stockings       Union Base-Ball Grounds    19
# 2        3  1871   Cleveland Forest Citys  National Association Grounds    10
# 3        4  1871     Fort Wayne Kekiongas                Hamilton Field     7
# 4        5  1871         New York Mutuals      Union Grounds (Brooklyn)    16
# ...    ...   ...                      ...                           ...   ...
# 2950  2951  2020      St. Louis Cardinals             Busch Stadium III    30
# 2951  2952  2020           Tampa Bay Rays               Tropicana Field    40
# 2952  2953  2020            Texas Rangers              Globe Life Field    22
# 2953  2954  2020        Toronto Blue Jays                  Sahlen Field    32
# 2954  2955  2020     Washington Nationals                Nationals Park    26
#
#       losses
# 0         10
# ...

# %%
columns = df.columns.tolist()
columns
# Out:
# ['id', 'year', 'name', 'park', 'wins', 'losses']

# %%
dtyap = df.dtypes
dtyap
# Out:
# id         int64
# year       int64
# name      object
# park      object
# wins       int64
# losses     int64
# dtype: object

# %%
total = df.shape[0]
total
# Out:
# 2955

# %%
df[:20]
# Out:
#     id  year                     name                               park  \
# 0    1  1871     Boston Red Stockings                South End Grounds I
# 1    2  1871  Chicago White Stockings            Union Base-Ball Grounds
# 2    3  1871   Cleveland Forest Citys       National Association Grounds
# 3    4  1871     Fort Wayne Kekiongas                     Hamilton Field
# 4    5  1871         New York Mutuals           Union Grounds (Brooklyn)
# 5    6  1871   Philadelphia Athletics           Jefferson Street Grounds
# 6    7  1871    Rockford Forest Citys  Agricultural Society Fair Grounds
# 7    8  1871           Troy Haymakers                 Haymakers' Grounds
# 8    9  1871      Washington Olympics                   Olympics Grounds
# 9   10  1872       Baltimore Canaries                     Newington Park
# 10  11  1872        Brooklyn Eckfords                      Union Grounds
# 11  12  1872       Brooklyn Atlantics                 Capitoline Grounds
# ...

# %%
df[2935:]
# Out:
#         id  year                           name                      park  \
# 2935  2936  2020                 Houston Astros          Minute Maid Park
# 2936  2937  2020             Kansas City Royals          Kauffman Stadium
# 2937  2938  2020  Los Angeles Angels of Anaheim  Angel Stadium of Anaheim
# 2938  2939  2020            Los Angeles Dodgers            Dodger Stadium
# 2939  2940  2020                  Miami Marlins              Marlins Park
# 2940  2941  2020              Milwaukee Brewers               Miller Park
# 2941  2942  2020                Minnesota Twins              Target Field
# 2942  2943  2020               New York Yankees        Yankee Stadium III
# 2943  2944  2020                  New York Mets                Citi Field
# 2944  2945  2020              Oakland Athletics             O.co Coliseum
# 2945  2946  2020          Philadelphia Phillies        Citizens Bank Park
# 2946  2947  2020             Pittsburgh Pirates                  PNC Park
# ...

# %%
df['Score'] = df.wins - df.losses
df
# Out:
#         id  year                     name                          park  wins  \
# 0        1  1871     Boston Red Stockings           South End Grounds I    20
# 1        2  1871  Chicago White Stockings       Union Base-Ball Grounds    19
# 2        3  1871   Cleveland Forest Citys  National Association Grounds    10
# 3        4  1871     Fort Wayne Kekiongas                Hamilton Field     7
# 4        5  1871         New York Mutuals      Union Grounds (Brooklyn)    16
# ...    ...   ...                      ...                           ...   ...
# 2950  2951  2020      St. Louis Cardinals             Busch Stadium III    30
# 2951  2952  2020           Tampa Bay Rays               Tropicana Field    40
# 2952  2953  2020            Texas Rangers              Globe Life Field    22
# 2953  2954  2020        Toronto Blue Jays                  Sahlen Field    32
# 2954  2955  2020     Washington Nationals                Nationals Park    26
#
#       losses  Score
# ...

# %%
df = pd.read_csv(filepath, index_col='id')
df
# Out:
#       year                     name                          park  wins  \
# id
# 1     1871     Boston Red Stockings           South End Grounds I    20
# 2     1871  Chicago White Stockings       Union Base-Ball Grounds    19
# 3     1871   Cleveland Forest Citys  National Association Grounds    10
# 4     1871     Fort Wayne Kekiongas                Hamilton Field     7
# 5     1871         New York Mutuals      Union Grounds (Brooklyn)    16
# ...    ...                      ...                           ...   ...
# 2951  2020      St. Louis Cardinals             Busch Stadium III    30
# 2952  2020           Tampa Bay Rays               Tropicana Field    40
# 2953  2020            Texas Rangers              Globe Life Field    22
# 2954  2020        Toronto Blue Jays                  Sahlen Field    32
# 2955  2020     Washington Nationals                Nationals Park    26
#
#       losses
# id
# 1         10
# 2          9
# 3         19
# 4         12
# 5         17
# ...

# %%
top = df[df['wins'] > 20]
top
# Out:
#       year                    name                      park  wins  losses
# id
# 6     1871  Philadelphia Athletics  Jefferson Street Grounds    21       7
# 10    1872      Baltimore Canaries            Newington Park    35      19
# 13    1872    Boston Red Stockings       South End Grounds I    39       8
# 16    1872        New York Mutuals  Union Grounds (Brooklyn)    34      20
# 17    1872  Philadelphia Athletics  Jefferson Street Grounds    30      14
# ...    ...                     ...                       ...   ...     ...
# 2951  2020     St. Louis Cardinals         Busch Stadium III    30      28
# 2952  2020          Tampa Bay Rays           Tropicana Field    40      20
# 2953  2020           Texas Rangers          Globe Life Field    22      38
# 2954  2020       Toronto Blue Jays              Sahlen Field    32      28
# 2955  2020    Washington Nationals            Nationals Park    26      34
#
# [2910 rows x 5 columns]

# %%
bottom = df[df['losses'] > 20]
bottom
# Out:
#       year                   name                               park  wins  \
# id
# 7     1871  Rockford Forest Citys  Agricultural Society Fair Grounds     4
# 11    1872      Brooklyn Eckfords                      Union Grounds     3
# 12    1872     Brooklyn Atlantics                 Capitoline Grounds     9
# 21    1873     Baltimore Canaries                     Newington Park    34
# 23    1873     Brooklyn Atlantics                      Union Grounds    17
# ...    ...                    ...                                ...   ...
# 2950  2020   San Francisco Giants                        Oracle Park    29
# 2951  2020    St. Louis Cardinals                  Busch Stadium III    30
# 2953  2020          Texas Rangers                   Globe Life Field    22
# 2954  2020      Toronto Blue Jays                       Sahlen Field    32
# 2955  2020   Washington Nationals                     Nationals Park    26
#
#       losses  Score
# id
# 7         21    -17
# ...

# %%
df['Score'] = df.wins - df.losses
df
# Out:
#       year                     name                          park  wins  \
# id
# 1     1871     Boston Red Stockings           South End Grounds I    20
# 2     1871  Chicago White Stockings       Union Base-Ball Grounds    19
# 3     1871   Cleveland Forest Citys  National Association Grounds    10
# 4     1871     Fort Wayne Kekiongas                Hamilton Field     7
# 5     1871         New York Mutuals      Union Grounds (Brooklyn)    16
# ...    ...                      ...                           ...   ...
# 2951  2020      St. Louis Cardinals             Busch Stadium III    30
# 2952  2020           Tampa Bay Rays               Tropicana Field    40
# 2953  2020            Texas Rangers              Globe Life Field    22
# 2954  2020        Toronto Blue Jays                  Sahlen Field    32
# 2955  2020     Washington Nationals                Nationals Park    26
#
#       losses  Score
# id
# 1         10     10
# 2          9     10
# 3         19     -9
# ...

# %%
bottom = df[df['Score'] < 0]
bottom
# Out:
#       year                    name                               park  wins  \
# id
# 3     1871  Cleveland Forest Citys       National Association Grounds    10
# 4     1871    Fort Wayne Kekiongas                     Hamilton Field     7
# 5     1871        New York Mutuals           Union Grounds (Brooklyn)    16
# 7     1871   Rockford Forest Citys  Agricultural Society Fair Grounds     4
# 8     1871          Troy Haymakers                 Haymakers' Grounds    13
# ...    ...                     ...                                ...   ...
# 2947  2020      Pittsburgh Pirates                           PNC Park    19
# 2949  2020        Seattle Mariners                      T-Mobile Park    27
# 2950  2020    San Francisco Giants                        Oracle Park    29
# 2953  2020           Texas Rangers                   Globe Life Field    22
# 2955  2020    Washington Nationals                     Nationals Park    26
#
#       losses  Score
# id
# 3         19     -9
# ...

# %%
top = df[df['Score'] > 0]
top
# Out:
#       year                     name                      park  wins  losses  \
# id
# 1     1871     Boston Red Stockings       South End Grounds I    20      10
# 2     1871  Chicago White Stockings   Union Base-Ball Grounds    19       9
# 6     1871   Philadelphia Athletics  Jefferson Street Grounds    21       7
# 10    1872       Baltimore Canaries            Newington Park    35      19
# 13    1872     Boston Red Stockings       South End Grounds I    39       8
# ...    ...                      ...                       ...   ...     ...
# 2945  2020        Oakland Athletics             O.co Coliseum    36      24
# 2948  2020         San Diego Padres                Petco Park    37      23
# 2951  2020      St. Louis Cardinals         Busch Stadium III    30      28
# 2952  2020           Tampa Bay Rays           Tropicana Field    40      20
# 2954  2020        Toronto Blue Jays              Sahlen Field    32      28
#
#       Score
# id
# 1        10
# 2        10
# ...

# %%
df['Status'] = np.where(df['Score'] > 0, 'Positive', 'Negative')
df
# Out:
#       year                     name                          park  wins  \
# id
# 1     1871     Boston Red Stockings           South End Grounds I    20
# 2     1871  Chicago White Stockings       Union Base-Ball Grounds    19
# 3     1871   Cleveland Forest Citys  National Association Grounds    10
# 4     1871     Fort Wayne Kekiongas                Hamilton Field     7
# 5     1871         New York Mutuals      Union Grounds (Brooklyn)    16
# ...    ...                      ...                           ...   ...
# 2951  2020      St. Louis Cardinals             Busch Stadium III    30
# 2952  2020           Tampa Bay Rays               Tropicana Field    40
# 2953  2020            Texas Rangers              Globe Life Field    22
# 2954  2020        Toronto Blue Jays                  Sahlen Field    32
# 2955  2020     Washington Nationals                Nationals Park    26
#
#       losses  Score    Status
# id
# 1         10     10  Positive
# 2          9     10  Positive
# ...

# %%
wins = np.array(df['wins'])
losses = np.array(df['losses'])
score = np.array(df['Score'])
avewin = int(np.average(wins))
aveloss = int(np.average(losses))
avescore = int(np.average(score))
print("Average team wins: " + str(avewin))
print("Average team losses: " + str(aveloss))
print("Average team score: " + str(avescore))
# Out:
# Average team wins: 74
# Average team losses: 74
# Average team losses: 0

# %%
wins = np.array(df['wins'])
losses = np.array(df['losses'])
score = np.array(df['Score'])
avewin = int(np.median(wins))
aveloss = int(np.median(losses))
avescore = int(np.median(score))
print("Average team wins: " + str(avewin))
print("Average team losses: " + str(aveloss))
print("Average team score: " + str(avescore))
# Out:
# Average team wins: 77
# Average team losses: 76
# Average team score: 1
